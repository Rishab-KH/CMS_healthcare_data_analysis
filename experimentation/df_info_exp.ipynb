# %%
import pandas as pd 

us_cities = pd.read_excel('/Users/rishabkhuba/Documents/Medicare_Pipeline/uscities.xlsx')

# %%
us_cities.head(3)
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36081       Queens
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18908608  11080.3  shape     False          True
# 1  34.1141 -118.4068    11922389   3184.7  shape     False          True
# 2  41.8375  -87.6866     8497759   4614.5  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# 1  America/Los_Angeles        1
# 2      America/Chicago        1
#
#                                                 zips          id
# 0  11229 11228 11226 11225 11224 11222 11221 1122...  1840034016
# 1  91367 90291 90293 90292 91316 91311 90035 9003...  1840020491
# ...

# %%
us_cities.shape
# Out:
# (31120, 17)

# %%
df_drug = pd.read_csv('/Users/rishabkhuba/Documents/Medicare_Pipeline/drug.csv')
# Out:
# /var/folders/5j/rksnclcn09j1c7_n7bc6nmhr0000gn/T/ipykernel_22897/2977478596.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_drug = pd.read_csv('/Users/rishabkhuba/Documents/Medicare_Pipeline/drug.csv')

# %%
df_drug.head()
# Out:
#   Prscrbr_Geo_Lvl Prscrbr_Geo_Cd Prscrbr_Geo_Desc  \
# 0           State              1          Alabama
# 1           State              1          Alabama
# 2           State              1          Alabama
# 3           State              1          Alabama
# 4           State              1          Alabama
#
#                        Brnd_Name                    Gnrc_Name  Tot_Prscrbrs  \
# 0  1st Tier Unifine Pentips Plus         Pen Needle, Diabetic            10
# 1                       Abacavir             Abacavir Sulfate            48
# 2            Abacavir-Lamivudine  Abacavir Sulfate/Lamivudine            30
# 3                        Abilify                 Aripiprazole            14
# 4               Abilify Maintena                 Aripiprazole           253
#
#    Tot_Clms  Tot_30day_Fills  Tot_Drug_Cst  Tot_Benes  ...  \
# 0        22             44.3        801.55        NaN  ...
# 1       455            496.0     133761.31       56.0  ...
# ...

# %%
df_drug.shape
# Out:
# (111812, 22)

# %%
df_prescriber = pd.read_csv('/Users/rishabkhuba/Documents/Medicare_Pipeline/prescriber.csv')

# %%
df_prescriber.head()
# Out:
#    Prscrbr_NPI Prscrbr_Last_Org_Name Prscrbr_First_Name Prscrbr_MI  \
# 0   1003000126             Enkeshafi            Ardalan        NaN
# 1   1003000142                Khalil             Rashid        NaN
# 2   1003000167               Escobar              Julio          E
# 3   1003000423               Velotta           Jennifer          A
# 4   1003000480             Rothchild              Kevin          B
#
#   Prscrbr_Crdntls Prscrbr_Gndr Prscrbr_Ent_Cd                 Prscrbr_St1  \
# 0            M.D.            M              I   6410 Rockledge Dr Ste 304
# 1            M.D.            M              I  4126 N Holland Sylvania Rd
# 2             DDS            M              I              5 Pine Cone Rd
# 3            M.D.            F              I            11100 Euclid Ave
# 4              MD            M              I            12605 E 16th Ave
#
#   Prscrbr_St2 Prscrbr_City  ... Bene_Male_Cnt  Bene_Race_Wht_Cnt  \
# ...

# %%
df_prescriber.shape
# Out:
# (1332309, 85)

# %%
df_prescriber_drug = pd.read_csv('/Users/rishabkhuba/Documents/Medicare_Pipeline/prescriber_drug.csv')
# Out:
# /var/folders/5j/rksnclcn09j1c7_n7bc6nmhr0000gn/T/ipykernel_22897/1403887804.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_prescriber_drug = pd.read_csv('/Users/rishabkhuba/Documents/Medicare_Pipeline/prescriber_drug.csv')

# %%
df_prescriber_drug.head()
# Out:
#    Prscrbr_NPI Prscrbr_Last_Org_Name Prscrbr_First_Name Prscrbr_City  \
# 0   1003000126             Enkeshafi            Ardalan     Bethesda
# 1   1003000126             Enkeshafi            Ardalan     Bethesda
# 2   1003000126             Enkeshafi            Ardalan     Bethesda
# 3   1003000126             Enkeshafi            Ardalan     Bethesda
# 4   1003000126             Enkeshafi            Ardalan     Bethesda
#
#   Prscrbr_State_Abrvtn Prscrbr_State_FIPS       Prscrbr_Type Prscrbr_Type_Src  \
# 0                   MD                 24  Internal Medicine  Claim-Specialty
# 1                   MD                 24  Internal Medicine  Claim-Specialty
# 2                   MD                 24  Internal Medicine  Claim-Specialty
# 3                   MD                 24  Internal Medicine  Claim-Specialty
# 4                   MD                 24  Internal Medicine  Claim-Specialty
#
#               Brnd_Name             Gnrc_Name  ...  Tot_Day_Suply  \
# ...

# %%
df_prescriber_drug.shape
# Out:
# (25869521, 22)

# %% [markdown]
# ## Preliminary Insights
#
# Dataset Overview:
#
# - Drug: ~112k entries
# - Prescriber: ~1.3M entries
# - Prescriber_drug: ~25M entries
# - US state: ~31k entries
